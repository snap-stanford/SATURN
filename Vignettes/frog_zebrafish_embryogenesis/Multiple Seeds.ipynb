# %% [markdown]
# # Replicate Figures 1, 2 and 3

# %% [markdown]
# To replicate SATURN results for frog and zebrafish embryogenesis you need to run SATURN 30 times with different seeds.
#
# To more easily do this analysis, we have provided a python script that will run SATURN a certain number of times.
#
#
# **NOTE: run the Train SATURN vignette first, `Vignettes/frog_zebrafish_embryogenesis/Train SATURN.ipynb`**

# %%
# Make a path fixed copy of the run file from the vignette
import pandas as pd
run_df = pd.read_csv("data/frog_zebrafish_run.csv")
run_df["path"] = ["Vignettes/frog_zebrafish_embryogenesis/" + path for path in run_df["path"] ]
run_df.to_csv("data/frog_zebrafish_run_multi.csv", index=False)

# %% [markdown]
# # Run the 30 seeds

# %% [markdown]
# *This will take a while*

# %%
# !cd ../../ ; python3 saturn_multiple_seeds.py \
                --run=Vignettes/frog_zebrafish_embryogenesis/data/frog_zebrafish_run_multi.csv --embedding_model=ESM2 \
                --gpus 7 8 9 \
                --seeds=30
# Out:
# ['7', '8', '9']
#   0%|                                                    | 0/30 [00:00<?, ?it/s]RUNNING SEED: 0 ON GPU:7
# RUNNING SEED: 1 ON GPU:8
# RUNNING SEED: 2 ON GPU:9
# Global seed set to 0
# Global seed set to 0
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.267735481262207, Avg Loss frog: 1861, Avg Lo
# Epoch 200: L1 Loss 0.0 Rank Loss 12.50074577331543, Avg Loss frog: 1861, Avg Los
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.08it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.19it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.381772994995117, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.19it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.70it/s]
#  10%|███▋                                 | 3/30 [2:25:12<21:46:51, 2904.13s/it]RUNNING SEED: 3 ON GPU:7
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:09<00:00, 15.74it/s]
#  13%|████▉                                | 4/30 [2:25:51<14:17:56, 1979.88s/it]RUNNING SEED: 4 ON GPU:9
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 13.62it/s]
#  17%|██████▎                               | 5/30 [2:28:48<9:48:03, 1411.35s/it]RUNNING SEED: 5 ON GPU:8
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.344212532043457, Avg Loss frog: 1863, Avg Lo
# Epoch 200: L1 Loss 0.0 Rank Loss 12.393857955932617, Avg Loss frog: 1861, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  6.83it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.03it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.232749938964844, Avg Loss frog: 1864, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.13it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.15it/s]
#  20%|███████▍                             | 6/30 [4:45:29<23:28:11, 3520.49s/it]RUNNING SEED: 6 ON GPU:9
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:09<00:00, 15.87it/s]
#  23%|████████▋                            | 7/30 [4:46:14<15:40:01, 2452.23s/it]RUNNING SEED: 7 ON GPU:7
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:09<00:00, 15.85it/s]
#  27%|█████████▊                           | 8/30 [4:48:12<10:38:00, 1740.01s/it]RUNNING SEED: 8 ON GPU:8
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.028584480285645, Avg Loss frog: 1860, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.18it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.137282371520996, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.24it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.030505180358887, Avg Loss frog: 1858, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.22it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.50it/s]
#  30%|███████████                          | 9/30 [7:14:34<22:37:10, 3877.62s/it]RUNNING SEED: 9 ON GPU:7
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.68it/s]
#  33%|████████████                        | 10/30 [7:15:31<15:07:16, 2721.82s/it]RUNNING SEED: 10 ON GPU:8
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 14.39it/s]
#  37%|█████████████▏                      | 11/30 [7:17:53<10:15:28, 1943.59s/it]RUNNING SEED: 11 ON GPU:9
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.455513000488281, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.09it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.195096015930176, Avg Loss frog: 1861, Avg Lo
# Epoch 200: L1 Loss 0.0 Rank Loss 12.082626342773438, Avg Loss frog: 1863, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.04it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.04it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.13it/s]
#  40%|██████████████▍                     | 12/30 [9:40:42<19:41:44, 3939.13s/it]RUNNING SEED: 12 ON GPU:9
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:09<00:00, 15.72it/s]
#  43%|███████████████▌                    | 13/30 [9:42:30<13:09:34, 2786.72s/it]RUNNING SEED: 13 ON GPU:7
#  17%|██████▉                                   | 26/157 [00:01<00:07, 17.67it/s]Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.62it/s]
#  47%|█████████████████▎                   | 14/30 [9:42:50<8:41:21, 1955.08s/it]RUNNING SEED: 14 ON GPU:8
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.540498733520508, Avg Loss frog: 1860, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.11it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.462255477905273, Avg Loss frog: 1860, Avg Lo
# Epoch 200: L1 Loss 0.0 Rank Loss 12.467185974121094, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.20it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.34it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.34it/s]
#  50%|█████████████████▌                 | 15/30 [12:03:36<16:16:13, 3904.89s/it]RUNNING SEED: 15 ON GPU:9
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 14.37it/s]
#  53%|██████████████████▋                | 16/30 [12:06:48<10:50:58, 2789.92s/it]RUNNING SEED: 16 ON GPU:7
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.19it/s]
# Global seed set to 0
#  57%|████████████████████▍               | 17/30 [12:06:57<7:03:37, 1955.20s/it]RUNNING SEED: 17 ON GPU:8
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.370464324951172, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:22<00:00,  7.06it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.168854713439941, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.15it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.021483421325684, Avg Loss frog: 1861, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.29it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.09it/s]
#  60%|█████████████████████              | 18/30 [14:30:48<13:11:45, 3958.75s/it]RUNNING SEED: 18 ON GPU:9
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:09<00:00, 15.72it/s]
#  63%|██████████████████████▊             | 19/30 [14:31:31<8:30:21, 2783.80s/it]RUNNING SEED: 19 ON GPU:8
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:11<00:00, 14.14it/s]
#  67%|████████████████████████            | 20/30 [14:33:15<5:29:56, 1979.67s/it]RUNNING SEED: 20 ON GPU:7
# Global seed set to 0
# Epoch 200: L1 Loss 0.0 Rank Loss 12.53934097290039, Avg Loss frog: 1861, Avg Los
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.22it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.221112251281738, Avg Loss frog: 1861, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.38it/s]
# Epoch 200: L1 Loss 0.0 Rank Loss 12.260889053344727, Avg Loss frog: 1862, Avg Lo
# 100%|█████████████████████████████████████████| 157/157 [00:21<00:00,  7.32it/s]
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.45it/s]
#  70%|█████████████████████████▏          | 21/30 [16:50:56<9:39:37, 3864.19s/it]RUNNING SEED: 21 ON GPU:8
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 15.59it/s]
#  73%|██████████████████████████▍         | 22/30 [16:52:32<6:04:29, 2733.73s/it]RUNNING SEED: 22 ON GPU:7
# Global seed set to 0
# 100%|█████████████████████████████████████████| 157/157 [00:10<00:00, 14.54it/s]
#  77%|███████████████████████████▌        | 23/30 [16:53:43<3:45:44, 1934.92s/it]RUNNING SEED: 23 ON GPU:9
# Global seed set to 0
# Epoch 196: L1 Loss 0.0 Rank Loss 12.489670753479004, Avg Loss frog: 1862, Avg Lo

# %% [markdown]
# # Score the 30 seeds

# %% [markdown]
# We now need to score each SATURN run. First, we create a csv file mapping each run to a path.

# %%
from glob import glob

fz_adatas = glob("../multiple_seeds_results/saturn_results/*ESM2*2000*8000*default*.h5ad")
fz_adatas = [path.replace("..", "Vignettes") for path in fz_adatas if "pretrain" not in path and "frog" in path]
seeds = [path.split("_")[-1].replace(".h5ad", "") for path in fz_adatas]
fz_adatas, seeds

import pandas as pd
score_df = pd.DataFrame()
score_df["seed"] = seeds
score_df["path"] = fz_adatas
display(score_df.head())
print(len(score_df))
score_df.to_csv("./data/fz_multi_seeds.csv", index=False)
# Out:
#   seed                                               path
# 0   16  Vignettes/multiple_seeds_results/saturn_result...
# 1    3  Vignettes/multiple_seeds_results/saturn_result...
# 2   27  Vignettes/multiple_seeds_results/saturn_result...
# 3   23  Vignettes/multiple_seeds_results/saturn_result...
# 4    7  Vignettes/multiple_seeds_results/saturn_result...
# 30

# %%
# !cd ../../ ; python3 score_adata.py --adata=Vignettes/frog_zebrafish_embryogenesis/data/fz_multi_seeds.csv --scores=1 \
                                 --multiple_files --species1=zebrafish --species2=frog --label=labels2 \
                                 --ct_map=Vignettes/frog_zebrafish_embryogenesis/data/frog_zebrafish_cell_type_map.csv
# Out:
# score_adata.py:1060: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if species_1 or species_2 is "human":
# score_adata.py:1065: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif species_1 or species_2 is "zebrafish":
# 0
#  47%|████████████████████                       | 14/30 [04:57<05:37, 21.09s/it]/lfs/hyperturing1/0/yanay/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 100%|███████████████████████████████████████████| 30/30 [11:31<00:00, 23.06s/it]
# 100%|███████████████████████████████████████████| 30/30 [08:26<00:00, 16.88s/it]
# Vignettes/frog_zebrafish_embryogenesis/data/fz_multi_seeds_default_scores.csv
#     seed  ...              Label
# 0     16  ...  zebrafish to frog
# 1      3  ...  zebrafish to frog
# 2     27  ...  zebrafish to frog
# 3     23  ...  zebrafish to frog
# 4      7  ...  zebrafish to frog
# 5     12  ...  zebrafish to frog
# 6      2  ...  zebrafish to frog
# 7     17  ...  zebrafish to frog
# 8     26  ...  zebrafish to frog
# 9     22  ...  zebrafish to frog
# 10    13  ...  zebrafish to frog
# 11     6  ...  zebrafish to frog
# 12     8  ...  zebrafish to frog
# 13    28  ...  zebrafish to frog
# 14    19  ...  zebrafish to frog
# 15     0  ...  zebrafish to frog
# 16    15  ...  zebrafish to frog
# 17    24  ...  zebrafish to frog
# 18    20  ...  zebrafish to frog
# 19    11  ...  zebrafish to frog
# 20     4  ...  zebrafish to frog
# 21    14  ...  zebrafish to frog
# 22     1  ...  zebrafish to frog
# 23    25  ...  zebrafish to frog
# 24    21  ...  zebrafish to frog
# 25     5  ...  zebrafish to frog
# 26    10  ...  zebrafish to frog
# 27     9  ...  zebrafish to frog
# 28    29  ...  zebrafish to frog
# 29    18  ...  zebrafish to frog
# 0     16  ...  frog to zebrafish
# 1      3  ...  frog to zebrafish
# 2     27  ...  frog to zebrafish
# 3     23  ...  frog to zebrafish
# 4      7  ...  frog to zebrafish
# 5     12  ...  frog to zebrafish
# 6      2  ...  frog to zebrafish
# 7     17  ...  frog to zebrafish
# 8     26  ...  frog to zebrafish
# 9     22  ...  frog to zebrafish
# 10    13  ...  frog to zebrafish
# 11     6  ...  frog to zebrafish
# 12     8  ...  frog to zebrafish
# 13    28  ...  frog to zebrafish
# 14    19  ...  frog to zebrafish
# 15     0  ...  frog to zebrafish
# 16    15  ...  frog to zebrafish
# 17    24  ...  frog to zebrafish
# 18    20  ...  frog to zebrafish
# 19    11  ...  frog to zebrafish
# 20     4  ...  frog to zebrafish
# 21    14  ...  frog to zebrafish
# 22     1  ...  frog to zebrafish
# 23    25  ...  frog to zebrafish
# 24    21  ...  frog to zebrafish
# 25     5  ...  frog to zebrafish
# 26    10  ...  frog to zebrafish
# 27     9  ...  frog to zebrafish
# 28    29  ...  frog to zebrafish
# 29    18  ...  frog to zebrafish
#
# [60 rows x 6 columns]

# %% [markdown]
# The script will save a copy with scores to `"./data/fz_multi_seeds_scores.csv"`

# %%
pd.read_csv("./data/fz_multi_seeds_scores.csv")
# Out:
#     seed                                               path
# 0     16  Vignettes/multiple_seeds_results/saturn_result...  \
# 1      3  Vignettes/multiple_seeds_results/saturn_result...
# 2     27  Vignettes/multiple_seeds_results/saturn_result...
# 3     23  Vignettes/multiple_seeds_results/saturn_result...
# 4      7  Vignettes/multiple_seeds_results/saturn_result...
# 5     12  Vignettes/multiple_seeds_results/saturn_result...
# 6      2  Vignettes/multiple_seeds_results/saturn_result...
# 7     17  Vignettes/multiple_seeds_results/saturn_result...
# 8     26  Vignettes/multiple_seeds_results/saturn_result...
# 9     22  Vignettes/multiple_seeds_results/saturn_result...
# 10    13  Vignettes/multiple_seeds_results/saturn_result...
# 11     6  Vignettes/multiple_seeds_results/saturn_result...
# 12     8  Vignettes/multiple_seeds_results/saturn_result...
# 13    28  Vignettes/multiple_seeds_results/saturn_result...
# 14    19  Vignettes/multiple_seeds_results/saturn_result...
# 15     0  Vignettes/multiple_seeds_results/saturn_result...
# 16    15  Vignettes/multiple_seeds_results/saturn_result...
# 17    24  Vignettes/multiple_seeds_results/saturn_result...
# 18    20  Vignettes/multiple_seeds_results/saturn_result...
# 19    11  Vignettes/multiple_seeds_results/saturn_result...
# 20     4  Vignettes/multiple_seeds_results/saturn_result...
# 21    14  Vignettes/multiple_seeds_results/saturn_result...
# 22     1  Vignettes/multiple_seeds_results/saturn_result...
# 23    25  Vignettes/multiple_seeds_results/saturn_result...
# 24    21  Vignettes/multiple_seeds_results/saturn_result...
# 25     5  Vignettes/multiple_seeds_results/saturn_result...
# 26    10  Vignettes/multiple_seeds_results/saturn_result...
# 27     9  Vignettes/multiple_seeds_results/saturn_result...
# 28    29  Vignettes/multiple_seeds_results/saturn_result...
# 29    18  Vignettes/multiple_seeds_results/saturn_result...
# 30    16  Vignettes/multiple_seeds_results/saturn_result...
# 31     3  Vignettes/multiple_seeds_results/saturn_result...
# 32    27  Vignettes/multiple_seeds_results/saturn_result...
# 33    23  Vignettes/multiple_seeds_results/saturn_result...
# 34     7  Vignettes/multiple_seeds_results/saturn_result...
# 35    12  Vignettes/multiple_seeds_results/saturn_result...
# 36     2  Vignettes/multiple_seeds_results/saturn_result...
# 37    17  Vignettes/multiple_seeds_results/saturn_result...
# 38    26  Vignettes/multiple_seeds_results/saturn_result...
# 39    22  Vignettes/multiple_seeds_results/saturn_result...
# 40    13  Vignettes/multiple_seeds_results/saturn_result...
# 41     6  Vignettes/multiple_seeds_results/saturn_result...
# 42     8  Vignettes/multiple_seeds_results/saturn_result...
# 43    28  Vignettes/multiple_seeds_results/saturn_result...
# 44    19  Vignettes/multiple_seeds_results/saturn_result...
# 45     0  Vignettes/multiple_seeds_results/saturn_result...
# 46    15  Vignettes/multiple_seeds_results/saturn_result...
# 47    24  Vignettes/multiple_seeds_results/saturn_result...
# 48    20  Vignettes/multiple_seeds_results/saturn_result...
# 49    11  Vignettes/multiple_seeds_results/saturn_result...
# 50     4  Vignettes/multiple_seeds_results/saturn_result...
# 51    14  Vignettes/multiple_seeds_results/saturn_result...
# 52     1  Vignettes/multiple_seeds_results/saturn_result...
# 53    25  Vignettes/multiple_seeds_results/saturn_result...
# 54    21  Vignettes/multiple_seeds_results/saturn_result...
# 55     5  Vignettes/multiple_seeds_results/saturn_result...
# 56    10  Vignettes/multiple_seeds_results/saturn_result...
# 57     9  Vignettes/multiple_seeds_results/saturn_result...
# 58    29  Vignettes/multiple_seeds_results/saturn_result...
# 59    18  Vignettes/multiple_seeds_results/saturn_result...
#
#     Logistic Regression  Balanced Regression  Reannotation              Label
# 0              0.829958             0.460089           NaN  zebrafish to frog
# 1              0.855068             0.524969           NaN  zebrafish to frog
# 2              0.833744             0.484727           NaN  zebrafish to frog
# 3              0.857358             0.535022           NaN  zebrafish to frog
# 4              0.856708             0.511298           NaN  zebrafish to frog
# 5              0.752092             0.507344           NaN  zebrafish to frog
# 6              0.850343             0.518007           NaN  zebrafish to frog
# 7              0.810347             0.479374           NaN  zebrafish to frog
# 8              0.860752             0.532518           NaN  zebrafish to frog
# 9              0.812214             0.502011           NaN  zebrafish to frog
# 10             0.762480             0.474979           NaN  zebrafish to frog
# 11             0.823490             0.466291           NaN  zebrafish to frog
# 12             0.730015             0.438840           NaN  zebrafish to frog
# 13             0.842678             0.493462           NaN  zebrafish to frog
# 14             0.850859             0.515585           NaN  zebrafish to frog
# 15             0.844112             0.500574           NaN  zebrafish to frog
# 16             0.849332             0.506352           NaN  zebrafish to frog
# 17             0.862888             0.531300           NaN  zebrafish to frog
# 18             0.844040             0.499626           NaN  zebrafish to frog
# 19             0.824893             0.510465           NaN  zebrafish to frog
# 20             0.856089             0.524054           NaN  zebrafish to frog
# 21             0.835777             0.475801           NaN  zebrafish to frog
# 22             0.858947             0.536604           NaN  zebrafish to frog
# 23             0.845629             0.506047           NaN  zebrafish to frog
# 24             0.830051             0.478972           NaN  zebrafish to frog
# 25             0.858462             0.528428           NaN  zebrafish to frog
# 26             0.858709             0.534936           NaN  zebrafish to frog
# 27             0.854439             0.531342           NaN  zebrafish to frog
# 28             0.870831             0.550736           NaN  zebrafish to frog
# 29             0.812008             0.475818           NaN  zebrafish to frog
# 30             0.777564             0.394779           NaN  frog to zebrafish
# 31             0.798346             0.440665           NaN  frog to zebrafish
# 32             0.771457             0.401126           NaN  frog to zebrafish
# 33             0.795932             0.428939           NaN  frog to zebrafish
# 34             0.847280             0.474573           NaN  frog to zebrafish
# 35             0.710072             0.411815           NaN  frog to zebrafish
# 36             0.858074             0.481147           NaN  frog to zebrafish
# 37             0.774471             0.385997           NaN  frog to zebrafish
# 38             0.858547             0.486640           NaN  frog to zebrafish
# 39             0.784760             0.416818           NaN  frog to zebrafish
# 40             0.810497             0.441770           NaN  frog to zebrafish
# 41             0.770558             0.389068           NaN  frog to zebrafish
# 42             0.779915             0.400409           NaN  frog to zebrafish
# 43             0.794464             0.433824           NaN  frog to zebrafish
# 44             0.797463             0.456120           NaN  frog to zebrafish
# 45             0.800256             0.448813           NaN  frog to zebrafish
# 46             0.785675             0.428275           NaN  frog to zebrafish
# 47             0.859194             0.486494           NaN  frog to zebrafish
# 48             0.796958             0.441607           NaN  frog to zebrafish
# 49             0.795348             0.434984           NaN  frog to zebrafish
# 50             0.800398             0.456548           NaN  frog to zebrafish
# 51             0.780783             0.405686           NaN  frog to zebrafish
# 52             0.800382             0.452676           NaN  frog to zebrafish
# 53             0.797510             0.449764           NaN  frog to zebrafish
# 54             0.771157             0.404945           NaN  frog to zebrafish
# 55             0.857600             0.479866           NaN  frog to zebrafish
# 56             0.800855             0.451946           NaN  frog to zebrafish
# 57             0.798741             0.442996           NaN  frog to zebrafish
# 58             0.858831             0.489070           NaN  frog to zebrafish
# 59             0.800571             0.433671           NaN  frog to zebrafish

# %%
pd.read_csv("./data/fz_multi_seeds_scores.csv")["Logistic Regression"].describe()
# Out:
# count    60.000000
# mean      0.817800
# std       0.037250
# min       0.710072
# 25%       0.795786
# 50%       0.817852
# 75%       0.854596
# max       0.870831
# Name: Logistic Regression, dtype: float64
