# %% [markdown]
# # Generate Protein Embeddings
#
# As an example, here's how to proccess the frog reference proteome with ESM1b.
#
# You can find proteome fastas on ENSEMBL: https://uswest.ensembl.org/info/data/ftp/index.html
#
# We use a pretrained Transformer model from https://github.com/facebookresearch/esm. These models were trained on hundreds of millions of protein sequences from across the tree of life.
#
# **NOTE:** These protein embedding scripts require an older version of the ESM Repo: you should checkout commit:
# [`839c5b82c6cd9e18baa7a88dcbed3bd4b6d48e47`](https://github.com/facebookresearch/esm/commit/839c5b82c6cd9e18baa7a88dcbed3bd4b6d48e47)
#
# **Clone the ESM repo.**

# %% [markdown]
# ## Step 1: Download reference proteome

# %%
# !mkdir data

# %%
import os
NAME = "Xenopus_tropicalis.UCB_Xtro_10.0.pep.all" # CHANGE THIS TO THE NAME OF THE REFERENCE PROTEOME YOU WANT
DATA_PATH = os.path.abspath(os.getcwd()) + "/data" # PATH TO DATA DIRECTORY (YOU CAN USE THE ONE IN THIS DIRECTORY)
ESM_PATH = "/lfs/local/0/yanay/esm/" # MAKE SURE TO CHANGE THIS TO THE PATH YOU CLONED THE ESM REPO TO ESM PATH
TORCH_HOME = "/dfs/project/cross-species/yanay/torch_home" # MAKE SURE TO CHANGE THIS TO YOUR DESIRED DIRECTORY
DEVICE=6 # GPU NUMBER, CHANGE THIS

# PATH TO ENSMBL PROTEOME FASTA, CHANGE THIS
FASTA_URL = "https://ftp.ensembl.org/pub/release-108/fasta/xenopus_tropicalis/pep/Xenopus_tropicalis.UCB_Xtro_10.0.pep.all.fa.gz"

# %%
# !wget -r {FASTA_URL} \
        -O data/{NAME}.fa.gz
# Out:
# WARNING: combining -O with -r or -p will mean that all downloaded content
# will be placed in the single file you specified.
#
# --2022-11-14 15:30:40--  https://ftp.ensembl.org/pub/release-108/fasta/xenopus_tropicalis/pep/Xenopus_tropicalis.UCB_Xtro_10.0.pep.all.fa.gz
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.139
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11316909 (11M) [application/x-gzip]
# Saving to: ‘data/Xenopus_tropicalis.UCB_Xtro_10.0.pep.all.fa.gz’
#
# data/Xenopus_tropic 100%[===================>]  10.79M   430KB/s    in 26s
#
# 2022-11-14 15:31:06 (429 KB/s) - ‘data/Xenopus_tropicalis.UCB_Xtro_10.0.pep.all.fa.gz’ saved [11316909/11316909]
#
# FINISHED --2022-11-14 15:31:06--
# Total wall clock time: 26s
# Downloaded: 1 files, 11M in 26s (429 KB/s)

# %%
# !gunzip data/{NAME}.fa.gz
# Out:
# gzip: data/Xenopus_tropicalis.UCB_Xtro_10.0.pep.all.fa already exists; do you wish to overwrite (y or n)? ^C

# %% [markdown]
# ## Step 2: Clean Fasta

# %%
# !python clean_fasta.py \
--data_path=./data/{NAME}.fa \
--save_path=./data/{NAME}.clean.fa
# Out:
# Number of original sequences = 49,792
# 100%|█████████████████████████████████| 49792/49792 [00:00<00:00, 146933.93it/s]
# Number of cleaned sequences = 49,792

# %% [markdown]
# ## Step 3: Run ESM

# %%
# THE MODELS ARE VERY LARGE AND TAKE A WHILE TO RUN

# !export TORCH_HOME={TORCH_HOME}; cd {ESM_PATH}/scripts/; \
CUDA_VISIBLE_DEVICES={DEVICE} python extract.py esm1b_t33_650M_UR50S \
{DATA_PATH}/{NAME}.clean.fa \
{DATA_PATH}/{NAME}.clean.fa_esm1b \
--include mean  --truncate
# Out:
# Transferred model to GPU
# Read /dfs/project/cross-species/yanay/code/SPEAR/protein_embeddings/data/Xenopus_tropicalis.UCB_Xtro_10.0.pep.all.clean.fa with 49792 sequences
# Processing 1 of 8762 batches (73 sequences)
# Processing 2 of 8762 batches (61 sequences)
# Processing 3 of 8762 batches (57 sequences)
# Processing 4 of 8762 batches (53 sequences)
# Processing 5 of 8762 batches (51 sequences)
# Processing 6 of 8762 batches (50 sequences)
# Processing 7 of 8762 batches (48 sequences)
# Processing 8 of 8762 batches (47 sequences)
# Processing 9 of 8762 batches (46 sequences)
# Processing 10 of 8762 batches (45 sequences)
# Processing 11 of 8762 batches (44 sequences)
# Processing 12 of 8762 batches (43 sequences)
# Processing 13 of 8762 batches (42 sequences)
# Processing 14 of 8762 batches (41 sequences)
# Processing 15 of 8762 batches (41 sequences)
# Processing 16 of 8762 batches (40 sequences)
# Processing 17 of 8762 batches (40 sequences)
# Processing 18 of 8762 batches (39 sequences)
# Processing 19 of 8762 batches (39 sequences)
# Processing 20 of 8762 batches (39 sequences)
# Processing 21 of 8762 batches (38 sequences)
# Processing 22 of 8762 batches (37 sequences)
# Processing 23 of 8762 batches (37 sequences)
# Processing 24 of 8762 batches (37 sequences)
# Processing 25 of 8762 batches (36 sequences)
# Processing 26 of 8762 batches (36 sequences)
# Processing 27 of 8762 batches (36 sequences)
# Processing 28 of 8762 batches (35 sequences)
# Processing 29 of 8762 batches (35 sequences)
# Processing 30 of 8762 batches (35 sequences)
# Processing 31 of 8762 batches (35 sequences)
# Processing 32 of 8762 batches (34 sequences)
# Processing 33 of 8762 batches (34 sequences)
# Processing 34 of 8762 batches (34 sequences)
# Processing 35 of 8762 batches (34 sequences)
# Processing 36 of 8762 batches (33 sequences)
# Processing 37 of 8762 batches (33 sequences)
# Processing 38 of 8762 batches (33 sequences)
# Processing 39 of 8762 batches (33 sequences)
# Processing 40 of 8762 batches (33 sequences)
# Processing 41 of 8762 batches (32 sequences)
# Processing 42 of 8762 batches (32 sequences)
# Processing 43 of 8762 batches (32 sequences)
# Processing 44 of 8762 batches (32 sequences)
# Processing 45 of 8762 batches (32 sequences)
# Processing 46 of 8762 batches (32 sequences)
# Processing 47 of 8762 batches (32 sequences)
# Processing 48 of 8762 batches (31 sequences)
# Processing 49 of 8762 batches (31 sequences)
# Processing 50 of 8762 batches (31 sequences)
# Processing 51 of 8762 batches (31 sequences)
# Processing 52 of 8762 batches (31 sequences)
# Processing 53 of 8762 batches (30 sequences)
# Processing 54 of 8762 batches (30 sequences)
# Processing 55 of 8762 batches (30 sequences)
# Processing 56 of 8762 batches (30 sequences)
# Processing 57 of 8762 batches (30 sequences)
# Processing 58 of 8762 batches (29 sequences)
# Processing 59 of 8762 batches (29 sequences)
# Processing 60 of 8762 batches (29 sequences)
# Processing 61 of 8762 batches (29 sequences)
# Processing 62 of 8762 batches (29 sequences)
# Processing 63 of 8762 batches (29 sequences)
# Processing 64 of 8762 batches (29 sequences)
# Processing 65 of 8762 batches (29 sequences)
# Processing 66 of 8762 batches (28 sequences)
# Processing 67 of 8762 batches (28 sequences)
# Processing 68 of 8762 batches (28 sequences)
# Processing 69 of 8762 batches (28 sequences)
# Processing 70 of 8762 batches (28 sequences)
# Processing 71 of 8762 batches (28 sequences)
# Processing 72 of 8762 batches (28 sequences)
# Processing 73 of 8762 batches (28 sequences)
# Processing 74 of 8762 batches (28 sequences)
# Processing 75 of 8762 batches (28 sequences)
# Processing 76 of 8762 batches (27 sequences)
# Processing 77 of 8762 batches (27 sequences)
# Processing 78 of 8762 batches (27 sequences)
# Processing 79 of 8762 batches (27 sequences)
# Processing 80 of 8762 batches (27 sequences)
# Processing 81 of 8762 batches (27 sequences)
# Processing 82 of 8762 batches (27 sequences)
# Processing 83 of 8762 batches (27 sequences)
# Processing 84 of 8762 batches (27 sequences)
# Processing 85 of 8762 batches (26 sequences)
# Processing 86 of 8762 batches (26 sequences)
# Processing 87 of 8762 batches (26 sequences)
# Processing 88 of 8762 batches (26 sequences)
# Processing 89 of 8762 batches (26 sequences)
# Processing 90 of 8762 batches (26 sequences)
# Processing 91 of 8762 batches (26 sequences)
# Processing 92 of 8762 batches (26 sequences)
# Processing 93 of 8762 batches (26 sequences)
# Processing 94 of 8762 batches (26 sequences)
# Processing 95 of 8762 batches (26 sequences)
# Processing 96 of 8762 batches (26 sequences)
# Processing 97 of 8762 batches (25 sequences)
# Processing 98 of 8762 batches (25 sequences)
# Processing 99 of 8762 batches (25 sequences)
# Processing 100 of 8762 batches (25 sequences)
# Processing 101 of 8762 batches (25 sequences)
# Processing 102 of 8762 batches (25 sequences)
# Processing 103 of 8762 batches (25 sequences)
# Processing 104 of 8762 batches (25 sequences)
# Processing 105 of 8762 batches (25 sequences)
# Processing 106 of 8762 batches (25 sequences)
# Processing 107 of 8762 batches (25 sequences)
# Processing 108 of 8762 batches (24 sequences)
# Processing 109 of 8762 batches (24 sequences)
# Processing 110 of 8762 batches (24 sequences)
# Processing 111 of 8762 batches (24 sequences)
# Processing 112 of 8762 batches (24 sequences)
# Processing 113 of 8762 batches (24 sequences)
# Processing 114 of 8762 batches (24 sequences)
# Processing 115 of 8762 batches (24 sequences)
# Processing 116 of 8762 batches (24 sequences)
# Processing 117 of 8762 batches (24 sequences)
# Processing 118 of 8762 batches (24 sequences)
# Processing 119 of 8762 batches (24 sequences)
# Processing 120 of 8762 batches (24 sequences)
# Processing 121 of 8762 batches (24 sequences)
# Processing 122 of 8762 batches (24 sequences)
# Processing 123 of 8762 batches (23 sequences)
# Processing 124 of 8762 batches (23 sequences)
# Processing 125 of 8762 batches (23 sequences)
# Processing 126 of 8762 batches (23 sequences)
# Processing 127 of 8762 batches (23 sequences)
# Processing 128 of 8762 batches (23 sequences)
# Processing 129 of 8762 batches (23 sequences)
# Processing 130 of 8762 batches (23 sequences)
# Processing 131 of 8762 batches (23 sequences)
# Processing 132 of 8762 batches (23 sequences)
# Processing 133 of 8762 batches (23 sequences)
# Processing 134 of 8762 batches (23 sequences)
# Processing 135 of 8762 batches (23 sequences)
# Processing 136 of 8762 batches (23 sequences)
# Processing 137 of 8762 batches (23 sequences)
# Processing 138 of 8762 batches (23 sequences)
# Processing 139 of 8762 batches (23 sequences)
# Processing 140 of 8762 batches (23 sequences)
# Processing 141 of 8762 batches (23 sequences)
# Processing 142 of 8762 batches (23 sequences)
# Processing 143 of 8762 batches (22 sequences)
# Processing 144 of 8762 batches (22 sequences)
# Processing 145 of 8762 batches (22 sequences)
# Processing 146 of 8762 batches (22 sequences)
# Processing 147 of 8762 batches (22 sequences)
# Processing 148 of 8762 batches (22 sequences)
# Processing 149 of 8762 batches (22 sequences)
# Processing 150 of 8762 batches (22 sequences)
# Processing 151 of 8762 batches (22 sequences)
# Processing 152 of 8762 batches (22 sequences)
# Processing 153 of 8762 batches (22 sequences)
# Processing 154 of 8762 batches (22 sequences)
# Processing 155 of 8762 batches (22 sequences)
# Processing 156 of 8762 batches (22 sequences)
# Processing 157 of 8762 batches (22 sequences)
# Processing 158 of 8762 batches (22 sequences)
# Processing 159 of 8762 batches (22 sequences)
# Processing 160 of 8762 batches (22 sequences)
# Processing 161 of 8762 batches (22 sequences)
# Processing 162 of 8762 batches (22 sequences)
# Processing 163 of 8762 batches (22 sequences)
# Processing 164 of 8762 batches (21 sequences)
# Processing 165 of 8762 batches (21 sequences)
# Processing 166 of 8762 batches (21 sequences)
# Processing 167 of 8762 batches (21 sequences)
# Processing 168 of 8762 batches (21 sequences)
# Processing 169 of 8762 batches (21 sequences)
# Processing 170 of 8762 batches (21 sequences)
# Processing 171 of 8762 batches (21 sequences)
# Processing 172 of 8762 batches (21 sequences)
# Processing 173 of 8762 batches (21 sequences)
# Processing 174 of 8762 batches (21 sequences)
# Processing 175 of 8762 batches (21 sequences)
# Processing 176 of 8762 batches (21 sequences)
# Processing 177 of 8762 batches (21 sequences)
# Processing 178 of 8762 batches (21 sequences)
# Processing 179 of 8762 batches (21 sequences)
# Processing 180 of 8762 batches (21 sequences)
# Processing 181 of 8762 batches (21 sequences)
# Processing 182 of 8762 batches (21 sequences)
# Processing 183 of 8762 batches (21 sequences)
# Processing 184 of 8762 batches (21 sequences)
# Processing 185 of 8762 batches (21 sequences)
# Processing 186 of 8762 batches (21 sequences)
# Processing 187 of 8762 batches (21 sequences)
# Processing 188 of 8762 batches (21 sequences)
# Processing 189 of 8762 batches (21 sequences)
# Processing 190 of 8762 batches (20 sequences)
# Processing 191 of 8762 batches (20 sequences)
# Processing 192 of 8762 batches (20 sequences)
# Processing 193 of 8762 batches (20 sequences)
# Processing 194 of 8762 batches (20 sequences)
# Processing 195 of 8762 batches (20 sequences)
# Processing 196 of 8762 batches (20 sequences)
# Processing 197 of 8762 batches (20 sequences)
# Processing 198 of 8762 batches (20 sequences)
# Processing 199 of 8762 batches (20 sequences)
# Processing 200 of 8762 batches (20 sequences)
# Processing 201 of 8762 batches (20 sequences)
# Processing 202 of 8762 batches (20 sequences)
# Processing 203 of 8762 batches (20 sequences)
# Processing 204 of 8762 batches (20 sequences)
# Processing 205 of 8762 batches (20 sequences)
# Processing 206 of 8762 batches (20 sequences)
# Processing 207 of 8762 batches (20 sequences)
# Processing 208 of 8762 batches (20 sequences)
# Processing 209 of 8762 batches (20 sequences)
# Processing 210 of 8762 batches (20 sequences)
# Processing 211 of 8762 batches (20 sequences)
# Processing 212 of 8762 batches (20 sequences)
# Processing 213 of 8762 batches (20 sequences)
# Processing 214 of 8762 batches (20 sequences)
# Processing 215 of 8762 batches (20 sequences)
# Processing 216 of 8762 batches (20 sequences)
# Processing 217 of 8762 batches (20 sequences)
# Processing 218 of 8762 batches (19 sequences)
# Processing 219 of 8762 batches (19 sequences)
# Processing 220 of 8762 batches (19 sequences)
# Processing 221 of 8762 batches (19 sequences)
# Processing 222 of 8762 batches (19 sequences)
# Processing 223 of 8762 batches (19 sequences)
# Processing 224 of 8762 batches (19 sequences)
# Processing 225 of 8762 batches (19 sequences)
# Processing 226 of 8762 batches (19 sequences)
# Processing 227 of 8762 batches (19 sequences)
# Processing 228 of 8762 batches (19 sequences)
# Processing 229 of 8762 batches (19 sequences)
# Processing 230 of 8762 batches (19 sequences)
# Processing 231 of 8762 batches (19 sequences)
# Processing 232 of 8762 batches (19 sequences)
# Processing 233 of 8762 batches (19 sequences)
# Processing 234 of 8762 batches (19 sequences)
# Processing 235 of 8762 batches (19 sequences)
# Processing 236 of 8762 batches (19 sequences)
# Processing 237 of 8762 batches (19 sequences)
# Processing 238 of 8762 batches (19 sequences)
# Processing 239 of 8762 batches (19 sequences)
# Processing 240 of 8762 batches (19 sequences)
# Processing 241 of 8762 batches (19 sequences)
# Processing 242 of 8762 batches (19 sequences)
# Processing 243 of 8762 batches (19 sequences)
# Processing 244 of 8762 batches (19 sequences)
# Processing 245 of 8762 batches (19 sequences)
# Processing 246 of 8762 batches (19 sequences)
# Processing 247 of 8762 batches (19 sequences)
# Processing 248 of 8762 batches (19 sequences)
# Processing 249 of 8762 batches (19 sequences)
# Processing 250 of 8762 batches (19 sequences)
# Processing 251 of 8762 batches (19 sequences)
# Processing 252 of 8762 batches (18 sequences)
# Processing 253 of 8762 batches (18 sequences)
# Processing 254 of 8762 batches (18 sequences)
# Processing 255 of 8762 batches (18 sequences)
# Processing 256 of 8762 batches (18 sequences)
# Processing 257 of 8762 batches (18 sequences)
# Processing 258 of 8762 batches (18 sequences)
# Processing 259 of 8762 batches (18 sequences)
# Processing 260 of 8762 batches (18 sequences)
# Processing 261 of 8762 batches (18 sequences)
# Processing 262 of 8762 batches (18 sequences)
# Processing 263 of 8762 batches (18 sequences)
# Processing 264 of 8762 batches (18 sequences)
# Processing 265 of 8762 batches (18 sequences)
# Processing 266 of 8762 batches (18 sequences)
# Processing 267 of 8762 batches (18 sequences)
# Processing 268 of 8762 batches (18 sequences)
# Processing 269 of 8762 batches (18 sequences)
# Processing 270 of 8762 batches (18 sequences)
# Processing 271 of 8762 batches (18 sequences)
# Processing 272 of 8762 batches (18 sequences)
# Processing 273 of 8762 batches (18 sequences)
# Processing 274 of 8762 batches (18 sequences)
# Processing 275 of 8762 batches (18 sequences)
# Processing 276 of 8762 batches (18 sequences)
# Processing 277 of 8762 batches (18 sequences)
# Processing 278 of 8762 batches (18 sequences)
# Processing 279 of 8762 batches (18 sequences)
# Processing 280 of 8762 batches (18 sequences)
# Processing 281 of 8762 batches (18 sequences)
# Processing 282 of 8762 batches (18 sequences)
# Processing 283 of 8762 batches (18 sequences)
# Processing 284 of 8762 batches (18 sequences)
# Processing 285 of 8762 batches (18 sequences)
# Processing 286 of 8762 batches (18 sequences)
# Processing 287 of 8762 batches (18 sequences)
# Processing 288 of 8762 batches (18 sequences)
# Processing 289 of 8762 batches (18 sequences)
# Processing 290 of 8762 batches (18 sequences)
# Processing 291 of 8762 batches (18 sequences)
# Processing 292 of 8762 batches (18 sequences)
# Processing 293 of 8762 batches (18 sequences)
# Processing 294 of 8762 batches (18 sequences)
# Processing 295 of 8762 batches (18 sequences)
# Processing 296 of 8762 batches (17 sequences)
# Processing 297 of 8762 batches (17 sequences)
# Processing 298 of 8762 batches (17 sequences)
# Processing 299 of 8762 batches (17 sequences)
# Processing 300 of 8762 batches (17 sequences)
# Processing 301 of 8762 batches (17 sequences)
# Processing 302 of 8762 batches (17 sequences)
# Processing 303 of 8762 batches (17 sequences)
# Processing 304 of 8762 batches (17 sequences)
# Processing 305 of 8762 batches (17 sequences)
# Processing 306 of 8762 batches (17 sequences)
# Processing 307 of 8762 batches (17 sequences)
# Processing 308 of 8762 batches (17 sequences)
# Processing 309 of 8762 batches (17 sequences)
# Processing 310 of 8762 batches (17 sequences)
# Processing 311 of 8762 batches (17 sequences)
# Processing 312 of 8762 batches (17 sequences)
# Processing 313 of 8762 batches (17 sequences)
# Processing 314 of 8762 batches (17 sequences)
# Processing 315 of 8762 batches (17 sequences)
# Processing 316 of 8762 batches (17 sequences)
# Processing 317 of 8762 batches (17 sequences)
# Processing 318 of 8762 batches (17 sequences)
# Processing 319 of 8762 batches (17 sequences)
# Processing 320 of 8762 batches (17 sequences)
# Processing 321 of 8762 batches (17 sequences)
# Processing 322 of 8762 batches (17 sequences)
# Processing 323 of 8762 batches (17 sequences)
# Processing 324 of 8762 batches (17 sequences)
# Processing 325 of 8762 batches (17 sequences)
# Processing 326 of 8762 batches (17 sequences)
# Processing 327 of 8762 batches (17 sequences)
# Processing 328 of 8762 batches (17 sequences)
# Processing 329 of 8762 batches (17 sequences)
# Processing 330 of 8762 batches (17 sequences)
# Processing 331 of 8762 batches (17 sequences)
# Processing 332 of 8762 batches (17 sequences)
# Processing 333 of 8762 batches (17 sequences)
# Processing 334 of 8762 batches (17 sequences)
# Processing 335 of 8762 batches (17 sequences)
# Processing 336 of 8762 batches (17 sequences)
# Processing 337 of 8762 batches (17 sequences)
# Processing 338 of 8762 batches (17 sequences)
# Processing 339 of 8762 batches (17 sequences)
# Processing 340 of 8762 batches (17 sequences)
# Processing 341 of 8762 batches (17 sequences)
# Processing 342 of 8762 batches (16 sequences)
# Processing 343 of 8762 batches (16 sequences)
# Processing 344 of 8762 batches (16 sequences)
# Processing 345 of 8762 batches (16 sequences)
# Processing 346 of 8762 batches (16 sequences)
# Processing 347 of 8762 batches (16 sequences)
# Processing 348 of 8762 batches (16 sequences)
# Processing 349 of 8762 batches (16 sequences)
# Processing 350 of 8762 batches (16 sequences)
# Processing 351 of 8762 batches (16 sequences)
# Processing 352 of 8762 batches (16 sequences)
# Processing 353 of 8762 batches (16 sequences)
# Processing 354 of 8762 batches (16 sequences)
# Processing 355 of 8762 batches (16 sequences)
# Processing 356 of 8762 batches (16 sequences)
# Processing 357 of 8762 batches (16 sequences)
# Processing 358 of 8762 batches (16 sequences)
# Processing 359 of 8762 batches (16 sequences)
# Processing 360 of 8762 batches (16 sequences)
# Processing 361 of 8762 batches (16 sequences)
# Processing 362 of 8762 batches (16 sequences)
# Processing 363 of 8762 batches (16 sequences)
# Processing 364 of 8762 batches (16 sequences)
# Processing 365 of 8762 batches (16 sequences)
# Processing 366 of 8762 batches (16 sequences)
# Processing 367 of 8762 batches (16 sequences)
# Processing 368 of 8762 batches (16 sequences)
# Processing 369 of 8762 batches (16 sequences)
# Processing 370 of 8762 batches (16 sequences)
# Processing 371 of 8762 batches (16 sequences)
# Processing 372 of 8762 batches (16 sequences)
# Processing 373 of 8762 batches (16 sequences)
# Processing 374 of 8762 batches (16 sequences)
# Processing 375 of 8762 batches (16 sequences)
# Processing 376 of 8762 batches (16 sequences)
# Processing 377 of 8762 batches (16 sequences)
# Processing 378 of 8762 batches (16 sequences)
# Processing 379 of 8762 batches (16 sequences)
# Processing 380 of 8762 batches (16 sequences)
# Processing 381 of 8762 batches (16 sequences)
# Processing 382 of 8762 batches (16 sequences)
# Processing 383 of 8762 batches (16 sequences)
# Processing 384 of 8762 batches (16 sequences)
# Processing 385 of 8762 batches (16 sequences)
# Processing 386 of 8762 batches (16 sequences)
# Processing 387 of 8762 batches (16 sequences)
# Processing 388 of 8762 batches (16 sequences)
# Processing 389 of 8762 batches (16 sequences)
# Processing 390 of 8762 batches (16 sequences)
# Processing 391 of 8762 batches (16 sequences)
# Processing 392 of 8762 batches (16 sequences)
# Processing 393 of 8762 batches (16 sequences)
# Processing 394 of 8762 batches (16 sequences)
# Processing 395 of 8762 batches (16 sequences)
# Processing 396 of 8762 batches (16 sequences)
# Processing 397 of 8762 batches (16 sequences)
# Processing 398 of 8762 batches (16 sequences)
# Processing 399 of 8762 batches (16 sequences)
# Processing 400 of 8762 batches (16 sequences)
# Processing 401 of 8762 batches (16 sequences)
# Processing 402 of 8762 batches (16 sequences)
# Processing 403 of 8762 batches (16 sequences)
# Processing 404 of 8762 batches (15 sequences)
# Processing 405 of 8762 batches (15 sequences)
# Processing 406 of 8762 batches (15 sequences)
# Processing 407 of 8762 batches (15 sequences)
# Processing 408 of 8762 batches (15 sequences)
# Processing 409 of 8762 batches (15 sequences)
# Processing 410 of 8762 batches (15 sequences)
# Processing 411 of 8762 batches (15 sequences)
# Processing 412 of 8762 batches (15 sequences)
# Processing 413 of 8762 batches (15 sequences)
# Processing 414 of 8762 batches (15 sequences)
# Processing 415 of 8762 batches (15 sequences)
# Processing 416 of 8762 batches (15 sequences)
# Processing 417 of 8762 batches (15 sequences)
# Processing 418 of 8762 batches (15 sequences)
# Processing 419 of 8762 batches (15 sequences)
# Processing 420 of 8762 batches (15 sequences)
# Processing 421 of 8762 batches (15 sequences)
# Processing 422 of 8762 batches (15 sequences)
# Processing 423 of 8762 batches (15 sequences)
# Processing 424 of 8762 batches (15 sequences)
# Processing 425 of 8762 batches (15 sequences)
# Processing 426 of 8762 batches (15 sequences)
# Processing 427 of 8762 batches (15 sequences)
# Processing 428 of 8762 batches (15 sequences)
# Processing 429 of 8762 batches (15 sequences)
# Processing 430 of 8762 batches (15 sequences)
# Processing 431 of 8762 batches (15 sequences)
# Processing 432 of 8762 batches (15 sequences)
# Processing 433 of 8762 batches (15 sequences)
# Processing 434 of 8762 batches (15 sequences)
# Processing 435 of 8762 batches (15 sequences)
# Processing 436 of 8762 batches (15 sequences)
# Processing 437 of 8762 batches (15 sequences)
# Processing 438 of 8762 batches (15 sequences)
# Processing 439 of 8762 batches (15 sequences)
# Processing 440 of 8762 batches (15 sequences)
# Processing 441 of 8762 batches (15 sequences)
# Processing 442 of 8762 batches (15 sequences)
# Processing 443 of 8762 batches (15 sequences)
# Processing 444 of 8762 batches (15 sequences)
# Processing 445 of 8762 batches (15 sequences)
# Processing 446 of 8762 batches (15 sequences)
# Processing 447 of 8762 batches (15 sequences)
# Processing 448 of 8762 batches (15 sequences)
# Processing 449 of 8762 batches (15 sequences)
# Processing 450 of 8762 batches (15 sequences)
# Processing 451 of 8762 batches (15 sequences)
# Processing 452 of 8762 batches (15 sequences)
# Processing 453 of 8762 batches (15 sequences)
# Processing 454 of 8762 batches (15 sequences)
# Processing 455 of 8762 batches (15 sequences)
# Processing 456 of 8762 batches (15 sequences)
# Processing 457 of 8762 batches (15 sequences)
# Processing 458 of 8762 batches (15 sequences)
# Processing 459 of 8762 batches (15 sequences)
# Processing 460 of 8762 batches (15 sequences)
# Processing 461 of 8762 batches (15 sequences)
# Processing 462 of 8762 batches (15 sequences)
# Processing 463 of 8762 batches (15 sequences)
# Processing 464 of 8762 batches (15 sequences)
# Processing 465 of 8762 batches (15 sequences)
# Processing 466 of 8762 batches (15 sequences)
# Processing 467 of 8762 batches (15 sequences)
# Processing 468 of 8762 batches (15 sequences)
# Processing 469 of 8762 batches (15 sequences)
# Processing 470 of 8762 batches (15 sequences)
# Processing 471 of 8762 batches (15 sequences)
# Processing 472 of 8762 batches (15 sequences)
# Processing 473 of 8762 batches (15 sequences)
# Processing 474 of 8762 batches (15 sequences)
# Processing 475 of 8762 batches (15 sequences)
# Processing 476 of 8762 batches (15 sequences)
# Processing 477 of 8762 batches (15 sequences)
# Processing 478 of 8762 batches (15 sequences)
# Processing 479 of 8762 batches (15 sequences)
# Processing 480 of 8762 batches (15 sequences)
# Processing 481 of 8762 batches (14 sequences)
# Processing 482 of 8762 batches (14 sequences)
# Processing 483 of 8762 batches (14 sequences)
# Processing 484 of 8762 batches (14 sequences)
# Processing 485 of 8762 batches (14 sequences)
# Processing 486 of 8762 batches (14 sequences)
# Processing 487 of 8762 batches (14 sequences)
# Processing 488 of 8762 batches (14 sequences)
# Processing 489 of 8762 batches (14 sequences)
# Processing 490 of 8762 batches (14 sequences)
# Processing 491 of 8762 batches (14 sequences)
# Processing 492 of 8762 batches (14 sequences)
# Processing 493 of 8762 batches (14 sequences)
# Processing 494 of 8762 batches (14 sequences)
# Processing 495 of 8762 batches (14 sequences)
# Processing 496 of 8762 batches (14 sequences)
# Processing 497 of 8762 batches (14 sequences)
# Processing 498 of 8762 batches (14 sequences)
# Processing 499 of 8762 batches (14 sequences)
# Processing 500 of 8762 batches (14 sequences)
# Processing 501 of 8762 batches (14 sequences)
# Processing 502 of 8762 batches (14 sequences)
# Processing 503 of 8762 batches (14 sequences)
# Processing 504 of 8762 batches (14 sequences)
# Processing 505 of 8762 batches (14 sequences)
# Processing 506 of 8762 batches (14 sequences)
# Processing 507 of 8762 batches (14 sequences)
# Processing 508 of 8762 batches (14 sequences)
# Processing 509 of 8762 batches (14 sequences)
# Processing 510 of 8762 batches (14 sequences)
# Processing 511 of 8762 batches (14 sequences)
# Processing 512 of 8762 batches (14 sequences)
# Processing 513 of 8762 batches (14 sequences)
# Processing 514 of 8762 batches (14 sequences)
# Processing 515 of 8762 batches (14 sequences)
# Processing 516 of 8762 batches (14 sequences)
# Processing 517 of 8762 batches (14 sequences)
# Processing 518 of 8762 batches (14 sequences)
# Processing 519 of 8762 batches (14 sequences)
# Processing 520 of 8762 batches (14 sequences)
# Processing 521 of 8762 batches (14 sequences)
# Processing 522 of 8762 batches (14 sequences)
# Processing 523 of 8762 batches (14 sequences)
# Processing 524 of 8762 batches (14 sequences)
# Processing 525 of 8762 batches (14 sequences)
# Processing 526 of 8762 batches (14 sequences)
# Processing 527 of 8762 batches (14 sequences)
# Processing 528 of 8762 batches (14 sequences)
# Processing 529 of 8762 batches (14 sequences)
# Processing 530 of 8762 batches (14 sequences)
# Processing 531 of 8762 batches (14 sequences)
# Processing 532 of 8762 batches (14 sequences)
# Processing 533 of 8762 batches (14 sequences)
# Processing 534 of 8762 batches (14 sequences)
# Processing 535 of 8762 batches (14 sequences)
# Processing 536 of 8762 batches (14 sequences)
# Processing 537 of 8762 batches (14 sequences)
# Processing 538 of 8762 batches (14 sequences)
# Processing 539 of 8762 batches (14 sequences)
# Processing 540 of 8762 batches (14 sequences)
# Processing 541 of 8762 batches (14 sequences)
# Processing 542 of 8762 batches (14 sequences)
# Processing 543 of 8762 batches (14 sequences)
# Processing 544 of 8762 batches (14 sequences)
# Processing 545 of 8762 batches (14 sequences)
# Processing 546 of 8762 batches (14 sequences)
# Processing 547 of 8762 batches (14 sequences)
# Processing 548 of 8762 batches (14 sequences)
# Processing 549 of 8762 batches (14 sequences)
# Processing 550 of 8762 batches (14 sequences)
# Processing 551 of 8762 batches (14 sequences)
# Processing 552 of 8762 batches (14 sequences)
# Processing 553 of 8762 batches (14 sequences)
# Processing 554 of 8762 batches (14 sequences)
# Processing 555 of 8762 batches (14 sequences)
# Processing 556 of 8762 batches (14 sequences)
# Processing 557 of 8762 batches (14 sequences)
# Processing 558 of 8762 batches (14 sequences)
# Processing 559 of 8762 batches (14 sequences)
# Processing 560 of 8762 batches (14 sequences)
# Processing 561 of 8762 batches (14 sequences)
# Processing 562 of 8762 batches (13 sequences)
# Processing 563 of 8762 batches (13 sequences)
# Processing 564 of 8762 batches (13 sequences)
# Processing 565 of 8762 batches (13 sequences)
# Processing 566 of 8762 batches (13 sequences)
# Processing 567 of 8762 batches (13 sequences)
# Processing 568 of 8762 batches (13 sequences)
# Processing 569 of 8762 batches (13 sequences)
# Processing 570 of 8762 batches (13 sequences)
# Processing 571 of 8762 batches (13 sequences)
# Processing 572 of 8762 batches (13 sequences)
# Processing 573 of 8762 batches (13 sequences)
# Processing 574 of 8762 batches (13 sequences)
# Processing 575 of 8762 batches (13 sequences)
# Processing 576 of 8762 batches (13 sequences)
# Processing 577 of 8762 batches (13 sequences)
# Processing 578 of 8762 batches (13 sequences)
# Processing 579 of 8762 batches (13 sequences)
# Processing 580 of 8762 batches (13 sequences)
# Processing 581 of 8762 batches (13 sequences)
# Processing 582 of 8762 batches (13 sequences)
# Processing 583 of 8762 batches (13 sequences)
# Processing 584 of 8762 batches (13 sequences)
# Processing 585 of 8762 batches (13 sequences)
# Processing 586 of 8762 batches (13 sequences)
# Processing 587 of 8762 batches (13 sequences)
# Processing 588 of 8762 batches (13 sequences)
# Processing 589 of 8762 batches (13 sequences)
# Processing 590 of 8762 batches (13 sequences)
# Processing 591 of 8762 batches (13 sequences)
# Processing 592 of 8762 batches (13 sequences)
# Processing 593 of 8762 batches (13 sequences)
# Processing 594 of 8762 batches (13 sequences)
# Processing 595 of 8762 batches (13 sequences)
# Processing 596 of 8762 batches (13 sequences)
# Processing 597 of 8762 batches (13 sequences)
# Processing 598 of 8762 batches (13 sequences)
# Processing 599 of 8762 batches (13 sequences)
# Processing 600 of 8762 batches (13 sequences)
# Processing 601 of 8762 batches (13 sequences)
# Processing 602 of 8762 batches (13 sequences)
# Processing 603 of 8762 batches (13 sequences)
# Processing 604 of 8762 batches (13 sequences)
# Processing 605 of 8762 batches (13 sequences)
# Processing 606 of 8762 batches (13 sequences)
# Processing 607 of 8762 batches (13 sequences)
# Processing 608 of 8762 batches (13 sequences)
# Processing 609 of 8762 batches (13 sequences)
# Processing 610 of 8762 batches (13 sequences)
# Processing 611 of 8762 batches (13 sequences)
# Processing 612 of 8762 batches (13 sequences)
# Processing 613 of 8762 batches (13 sequences)
# Processing 614 of 8762 batches (13 sequences)
# Processing 615 of 8762 batches (13 sequences)
# Processing 616 of 8762 batches (13 sequences)
# Processing 617 of 8762 batches (13 sequences)
# Processing 618 of 8762 batches (13 sequences)
# Processing 619 of 8762 batches (13 sequences)
# Processing 620 of 8762 batches (13 sequences)
# Processing 621 of 8762 batches (13 sequences)
# Processing 622 of 8762 batches (13 sequences)
# Processing 623 of 8762 batches (13 sequences)
# Processing 624 of 8762 batches (13 sequences)
# Processing 625 of 8762 batches (13 sequences)
# Processing 626 of 8762 batches (13 sequences)
# Processing 627 of 8762 batches (13 sequences)
# Processing 628 of 8762 batches (13 sequences)
# Processing 629 of 8762 batches (13 sequences)
# Processing 630 of 8762 batches (13 sequences)
# Processing 631 of 8762 batches (13 sequences)
# Processing 632 of 8762 batches (13 sequences)
# Processing 633 of 8762 batches (13 sequences)
# Processing 634 of 8762 batches (13 sequences)
# Processing 635 of 8762 batches (13 sequences)
# Processing 636 of 8762 batches (13 sequences)
# Processing 637 of 8762 batches (13 sequences)
# Processing 638 of 8762 batches (13 sequences)
# Processing 639 of 8762 batches (13 sequences)
# Processing 640 of 8762 batches (13 sequences)
# Processing 641 of 8762 batches (13 sequences)
# Processing 642 of 8762 batches (13 sequences)
# Processing 643 of 8762 batches (13 sequences)
# Processing 644 of 8762 batches (13 sequences)
# Processing 645 of 8762 batches (13 sequences)
# Processing 646 of 8762 batches (13 sequences)
# Processing 647 of 8762 batches (13 sequences)
# Processing 648 of 8762 batches (13 sequences)
# Processing 649 of 8762 batches (13 sequences)
# Processing 650 of 8762 batches (13 sequences)
# Processing 651 of 8762 batches (13 sequences)
# Processing 652 of 8762 batches (13 sequences)
# Processing 653 of 8762 batches (13 sequences)
# Processing 654 of 8762 batches (13 sequences)
# Processing 655 of 8762 batches (13 sequences)
# Processing 656 of 8762 batches (13 sequences)
# Processing 657 of 8762 batches (13 sequences)
# Processing 658 of 8762 batches (13 sequences)
# Processing 659 of 8762 batches (13 sequences)
# Processing 660 of 8762 batches (13 sequences)
# Processing 661 of 8762 batches (13 sequences)
# Processing 662 of 8762 batches (13 sequences)
# Processing 663 of 8762 batches (13 sequences)
# Processing 664 of 8762 batches (13 sequences)
# Processing 665 of 8762 batches (13 sequences)
# Processing 666 of 8762 batches (13 sequences)
# Processing 667 of 8762 batches (13 sequences)
# Processing 668 of 8762 batches (13 sequences)
# Processing 669 of 8762 batches (13 sequences)
# Processing 670 of 8762 batches (13 sequences)
# Processing 671 of 8762 batches (13 sequences)
# Processing 672 of 8762 batches (13 sequences)
# Processing 673 of 8762 batches (13 sequences)
# Processing 674 of 8762 batches (13 sequences)
# Processing 675 of 8762 batches (13 sequences)
# Processing 676 of 8762 batches (13 sequences)
# Processing 677 of 8762 batches (13 sequences)
# Processing 678 of 8762 batches (13 sequences)
# Processing 679 of 8762 batches (13 sequences)
# Processing 680 of 8762 batches (13 sequences)
# Processing 681 of 8762 batches (13 sequences)
# Processing 682 of 8762 batches (13 sequences)
# Processing 683 of 8762 batches (13 sequences)
# Processing 684 of 8762 batches (13 sequences)
# Processing 685 of 8762 batches (13 sequences)
# Processing 686 of 8762 batches (13 sequences)
# Processing 687 of 8762 batches (13 sequences)
# Processing 688 of 8762 batches (13 sequences)
# Processing 689 of 8762 batches (13 sequences)
# Processing 690 of 8762 batches (13 sequences)
# Processing 691 of 8762 batches (13 sequences)
# Processing 692 of 8762 batches (13 sequences)
# Processing 693 of 8762 batches (13 sequences)
# Processing 694 of 8762 batches (13 sequences)
# Processing 695 of 8762 batches (13 sequences)
# Processing 696 of 8762 batches (13 sequences)
# Processing 697 of 8762 batches (13 sequences)
# Processing 698 of 8762 batches (13 sequences)
# Processing 699 of 8762 batches (13 sequences)
# Processing 700 of 8762 batches (13 sequences)
# Processing 701 of 8762 batches (13 sequences)
# Processing 702 of 8762 batches (13 sequences)
# Processing 703 of 8762 batches (13 sequences)
# Processing 704 of 8762 batches (13 sequences)
# Processing 705 of 8762 batches (13 sequences)
# Processing 706 of 8762 batches (13 sequences)
# Processing 707 of 8762 batches (12 sequences)
# Processing 708 of 8762 batches (12 sequences)
# Processing 709 of 8762 batches (12 sequences)
# Processing 710 of 8762 batches (12 sequences)
# Processing 711 of 8762 batches (12 sequences)
# Processing 712 of 8762 batches (12 sequences)
# Processing 713 of 8762 batches (12 sequences)
# Processing 714 of 8762 batches (12 sequences)
# Processing 715 of 8762 batches (12 sequences)
# Processing 716 of 8762 batches (12 sequences)
# Processing 717 of 8762 batches (12 sequences)
# Processing 718 of 8762 batches (12 sequences)
# Processing 719 of 8762 batches (12 sequences)
# Processing 720 of 8762 batches (12 sequences)
# Processing 721 of 8762 batches (12 sequences)
# Processing 722 of 8762 batches (12 sequences)
# Processing 723 of 8762 batches (12 sequences)
# Processing 724 of 8762 batches (12 sequences)
# Processing 725 of 8762 batches (12 sequences)
# Processing 726 of 8762 batches (12 sequences)
# Processing 727 of 8762 batches (12 sequences)
# Processing 728 of 8762 batches (12 sequences)
# Processing 729 of 8762 batches (12 sequences)
# Processing 730 of 8762 batches (12 sequences)
# Processing 731 of 8762 batches (12 sequences)
# Processing 732 of 8762 batches (12 sequences)
# Processing 733 of 8762 batches (12 sequences)
# Processing 734 of 8762 batches (12 sequences)
# Processing 735 of 8762 batches (12 sequences)
# Processing 736 of 8762 batches (12 sequences)
# Processing 737 of 8762 batches (12 sequences)
# Processing 738 of 8762 batches (12 sequences)
# Processing 739 of 8762 batches (12 sequences)
# Processing 740 of 8762 batches (12 sequences)
# Processing 741 of 8762 batches (12 sequences)
# Processing 742 of 8762 batches (12 sequences)
# Processing 743 of 8762 batches (12 sequences)
# Processing 744 of 8762 batches (12 sequences)
# Processing 745 of 8762 batches (12 sequences)
# Processing 746 of 8762 batches (12 sequences)
# Processing 747 of 8762 batches (12 sequences)
# Processing 748 of 8762 batches (12 sequences)
# Processing 749 of 8762 batches (12 sequences)
# Processing 750 of 8762 batches (12 sequences)
# Processing 751 of 8762 batches (12 sequences)
# Processing 752 of 8762 batches (12 sequences)
# Processing 753 of 8762 batches (12 sequences)
# Processing 754 of 8762 batches (12 sequences)
# Processing 755 of 8762 batches (12 sequences)
# Processing 756 of 8762 batches (12 sequences)
# Processing 757 of 8762 batches (12 sequences)
# Processing 758 of 8762 batches (12 sequences)
# Processing 759 of 8762 batches (12 sequences)
# Processing 760 of 8762 batches (12 sequences)
# Processing 761 of 8762 batches (12 sequences)
# Processing 762 of 8762 batches (12 sequences)
# Processing 763 of 8762 batches (12 sequences)
# Processing 764 of 8762 batches (12 sequences)
# Processing 765 of 8762 batches (12 sequences)
# Processing 766 of 8762 batches (12 sequences)
# Processing 767 of 8762 batches (12 sequences)
# Processing 768 of 8762 batches (12 sequences)
# Processing 769 of 8762 batches (12 sequences)
# Processing 770 of 8762 batches (12 sequences)
# Processing 771 of 8762 batches (12 sequences)
# Processing 772 of 8762 batches (12 sequences)
# Processing 773 of 8762 batches (12 sequences)
# Processing 774 of 8762 batches (12 sequences)
# Processing 775 of 8762 batches (12 sequences)
# Processing 776 of 8762 batches (12 sequences)
# Processing 777 of 8762 batches (12 sequences)
# Processing 778 of 8762 batches (12 sequences)
# Processing 779 of 8762 batches (12 sequences)
# Processing 780 of 8762 batches (12 sequences)
# Processing 781 of 8762 batches (12 sequences)
# Processing 782 of 8762 batches (12 sequences)
# Processing 783 of 8762 batches (12 sequences)
# Processing 784 of 8762 batches (12 sequences)
# Processing 785 of 8762 batches (12 sequences)
# Processing 786 of 8762 batches (12 sequences)
# Processing 787 of 8762 batches (12 sequences)
# Processing 788 of 8762 batches (12 sequences)
# Processing 789 of 8762 batches (12 sequences)
# Processing 790 of 8762 batches (12 sequences)
# Processing 791 of 8762 batches (12 sequences)
# Processing 792 of 8762 batches (12 sequences)
# Processing 793 of 8762 batches (12 sequences)
# Processing 794 of 8762 batches (12 sequences)
# Processing 795 of 8762 batches (12 sequences)
# Processing 796 of 8762 batches (12 sequences)
# Processing 797 of 8762 batches (12 sequences)
# Processing 798 of 8762 batches (12 sequences)
# Processing 799 of 8762 batches (12 sequences)
# Processing 800 of 8762 batches (12 sequences)
# Processing 801 of 8762 batches (12 sequences)
# Processing 802 of 8762 batches (12 sequences)
# Processing 803 of 8762 batches (12 sequences)
# Processing 804 of 8762 batches (12 sequences)
# Processing 805 of 8762 batches (12 sequences)
# Processing 806 of 8762 batches (12 sequences)
# Processing 807 of 8762 batches (12 sequences)
# Processing 808 of 8762 batches (12 sequences)
# Processing 809 of 8762 batches (12 sequences)
# Processing 810 of 8762 batches (12 sequences)
# Processing 811 of 8762 batches (12 sequences)
# Processing 812 of 8762 batches (12 sequences)
# Processing 813 of 8762 batches (12 sequences)
# Processing 814 of 8762 batches (12 sequences)
# Processing 815 of 8762 batches (12 sequences)
# Processing 816 of 8762 batches (12 sequences)
# Processing 817 of 8762 batches (12 sequences)
# Processing 818 of 8762 batches (12 sequences)
# Processing 819 of 8762 batches (12 sequences)
# Processing 820 of 8762 batches (12 sequences)
# Processing 821 of 8762 batches (12 sequences)
# Processing 822 of 8762 batches (12 sequences)
# Processing 823 of 8762 batches (12 sequences)
# Processing 824 of 8762 batches (12 sequences)
# Processing 825 of 8762 batches (12 sequences)
# Processing 826 of 8762 batches (12 sequences)
# Processing 827 of 8762 batches (12 sequences)
# Processing 828 of 8762 batches (12 sequences)
# Processing 829 of 8762 batches (12 sequences)
# Processing 830 of 8762 batches (12 sequences)
# Processing 831 of 8762 batches (12 sequences)
# Processing 832 of 8762 batches (12 sequences)
# Processing 833 of 8762 batches (12 sequences)
# Processing 834 of 8762 batches (12 sequences)
# Processing 835 of 8762 batches (12 sequences)
# Processing 836 of 8762 batches (12 sequences)
# Processing 837 of 8762 batches (12 sequences)
# Processing 838 of 8762 batches (12 sequences)
# Processing 839 of 8762 batches (12 sequences)
# Processing 840 of 8762 batches (12 sequences)
# Processing 841 of 8762 batches (12 sequences)
# Processing 842 of 8762 batches (12 sequences)
# Processing 843 of 8762 batches (12 sequences)
# Processing 844 of 8762 batches (12 sequences)
# Processing 845 of 8762 batches (12 sequences)
# Processing 846 of 8762 batches (12 sequences)
# Processing 847 of 8762 batches (12 sequences)
# Processing 848 of 8762 batches (12 sequences)
# Processing 849 of 8762 batches (12 sequences)
# Processing 850 of 8762 batches (12 sequences)
# Processing 851 of 8762 batches (12 sequences)
# Processing 852 of 8762 batches (12 sequences)
# Processing 853 of 8762 batches (12 sequences)
# Processing 854 of 8762 batches (12 sequences)
# Processing 855 of 8762 batches (12 sequences)
# Processing 856 of 8762 batches (12 sequences)
# Processing 857 of 8762 batches (12 sequences)
# Processing 858 of 8762 batches (12 sequences)
# Processing 859 of 8762 batches (12 sequences)
# Processing 860 of 8762 batches (12 sequences)
# Processing 861 of 8762 batches (12 sequences)
# Processing 862 of 8762 batches (12 sequences)
# Processing 863 of 8762 batches (12 sequences)
# Processing 864 of 8762 batches (12 sequences)
# Processing 865 of 8762 batches (12 sequences)
# Processing 866 of 8762 batches (12 sequences)
# Processing 867 of 8762 batches (12 sequences)
# Processing 868 of 8762 batches (12 sequences)
# Processing 869 of 8762 batches (12 sequences)
# Processing 870 of 8762 batches (12 sequences)
# Processing 871 of 8762 batches (12 sequences)
# Processing 872 of 8762 batches (12 sequences)
# Processing 873 of 8762 batches (12 sequences)
# Processing 874 of 8762 batches (12 sequences)
# Processing 875 of 8762 batches (12 sequences)
# Processing 876 of 8762 batches (12 sequences)
# Processing 877 of 8762 batches (12 sequences)
# Processing 878 of 8762 batches (12 sequences)
# Processing 879 of 8762 batches (12 sequences)
# Processing 880 of 8762 batches (12 sequences)
# Processing 881 of 8762 batches (12 sequences)
# Processing 882 of 8762 batches (12 sequences)
# Processing 883 of 8762 batches (12 sequences)
# Processing 884 of 8762 batches (12 sequences)
# Processing 885 of 8762 batches (12 sequences)
# Processing 886 of 8762 batches (12 sequences)
# Processing 887 of 8762 batches (12 sequences)
# Processing 888 of 8762 batches (12 sequences)
# Processing 889 of 8762 batches (12 sequences)
# Processing 890 of 8762 batches (12 sequences)
# Processing 891 of 8762 batches (12 sequences)
# Processing 892 of 8762 batches (12 sequences)
# Processing 893 of 8762 batches (12 sequences)
# Processing 894 of 8762 batches (12 sequences)
# Processing 895 of 8762 batches (12 sequences)
# Processing 896 of 8762 batches (12 sequences)
# Processing 897 of 8762 batches (12 sequences)
# Processing 898 of 8762 batches (12 sequences)
# Processing 899 of 8762 batches (12 sequences)
# Processing 900 of 8762 batches (12 sequences)
# Processing 901 of 8762 batches (12 sequences)
# Processing 902 of 8762 batches (12 sequences)
# Processing 903 of 8762 batches (12 sequences)
# Processing 904 of 8762 batches (12 sequences)
# Processing 905 of 8762 batches (12 sequences)
# Processing 906 of 8762 batches (12 sequences)
# Processing 907 of 8762 batches (12 sequences)
# Processing 908 of 8762 batches (11 sequences)
# Processing 909 of 8762 batches (11 sequences)
# Processing 910 of 8762 batches (11 sequences)
# Processing 911 of 8762 batches (11 sequences)
# Processing 912 of 8762 batches (11 sequences)
# Processing 913 of 8762 batches (11 sequences)
# Processing 914 of 8762 batches (11 sequences)
# Processing 915 of 8762 batches (11 sequences)
# Processing 916 of 8762 batches (11 sequences)
# Processing 917 of 8762 batches (11 sequences)
# Processing 918 of 8762 batches (11 sequences)
# Processing 919 of 8762 batches (11 sequences)
# Processing 920 of 8762 batches (11 sequences)
# Processing 921 of 8762 batches (11 sequences)
# Processing 922 of 8762 batches (11 sequences)
# Processing 923 of 8762 batches (11 sequences)
# Processing 924 of 8762 batches (11 sequences)
# Processing 925 of 8762 batches (11 sequences)
# Processing 926 of 8762 batches (11 sequences)
# Processing 927 of 8762 batches (11 sequences)
# Processing 928 of 8762 batches (11 sequences)
# Processing 929 of 8762 batches (11 sequences)
# Processing 930 of 8762 batches (11 sequences)
# Processing 931 of 8762 batches (11 sequences)
# Processing 932 of 8762 batches (11 sequences)
# Processing 933 of 8762 batches (11 sequences)
# Processing 934 of 8762 batches (11 sequences)
# Processing 935 of 8762 batches (11 sequences)
# Processing 936 of 8762 batches (11 sequences)
# Processing 937 of 8762 batches (11 sequences)
# Processing 938 of 8762 batches (11 sequences)
# Processing 939 of 8762 batches (11 sequences)
# Processing 940 of 8762 batches (11 sequences)
# Processing 941 of 8762 batches (11 sequences)
# Processing 942 of 8762 batches (11 sequences)
# Processing 943 of 8762 batches (11 sequences)
# Processing 944 of 8762 batches (11 sequences)
# Processing 945 of 8762 batches (11 sequences)
# Processing 946 of 8762 batches (11 sequences)
# Processing 947 of 8762 batches (11 sequences)
# Processing 948 of 8762 batches (11 sequences)
# Processing 949 of 8762 batches (11 sequences)
# Processing 950 of 8762 batches (11 sequences)
# Processing 951 of 8762 batches (11 sequences)
# Processing 952 of 8762 batches (11 sequences)
# Processing 953 of 8762 batches (11 sequences)
# Processing 954 of 8762 batches (11 sequences)
# Processing 955 of 8762 batches (11 sequences)
# Processing 956 of 8762 batches (11 sequences)
# Processing 957 of 8762 batches (11 sequences)
# Processing 958 of 8762 batches (11 sequences)
# Processing 959 of 8762 batches (11 sequences)
# Processing 960 of 8762 batches (11 sequences)
# Processing 961 of 8762 batches (11 sequences)
# Processing 962 of 8762 batches (11 sequences)
# Processing 963 of 8762 batches (11 sequences)
# Processing 964 of 8762 batches (11 sequences)
# Processing 965 of 8762 batches (11 sequences)
# Processing 966 of 8762 batches (11 sequences)
# Processing 967 of 8762 batches (11 sequences)
# Processing 968 of 8762 batches (11 sequences)
# Processing 969 of 8762 batches (11 sequences)
# Processing 970 of 8762 batches (11 sequences)
# Processing 971 of 8762 batches (11 sequences)
# Processing 972 of 8762 batches (11 sequences)
# Processing 973 of 8762 batches (11 sequences)
# Processing 974 of 8762 batches (11 sequences)
# Processing 975 of 8762 batches (11 sequences)
# Processing 976 of 8762 batches (11 sequences)
# Processing 977 of 8762 batches (11 sequences)
# Processing 978 of 8762 batches (11 sequences)
# Processing 979 of 8762 batches (11 sequences)
# Processing 980 of 8762 batches (11 sequences)
# Processing 981 of 8762 batches (11 sequences)
# Processing 982 of 8762 batches (11 sequences)
# Processing 983 of 8762 batches (11 sequences)
# Processing 984 of 8762 batches (11 sequences)
# Processing 985 of 8762 batches (11 sequences)
# Processing 986 of 8762 batches (11 sequences)
# Processing 987 of 8762 batches (11 sequences)
# Processing 988 of 8762 batches (11 sequences)
# Processing 989 of 8762 batches (11 sequences)
# Processing 990 of 8762 batches (11 sequences)
# Processing 991 of 8762 batches (11 sequences)
# Processing 992 of 8762 batches (11 sequences)
# Processing 993 of 8762 batches (11 sequences)
# Processing 994 of 8762 batches (11 sequences)
# Processing 995 of 8762 batches (11 sequences)
# Processing 996 of 8762 batches (11 sequences)
# Processing 997 of 8762 batches (11 sequences)
# Processing 998 of 8762 batches (11 sequences)
# Processing 999 of 8762 batches (11 sequences)
# Processing 1000 of 8762 batches (11 sequences)
# Processing 1001 of 8762 batches (11 sequences)
# Processing 1002 of 8762 batches (11 sequences)
# Processing 1003 of 8762 batches (11 sequences)
# Processing 1004 of 8762 batches (11 sequences)
# Processing 1005 of 8762 batches (11 sequences)
# Processing 1006 of 8762 batches (11 sequences)
# Processing 1007 of 8762 batches (11 sequences)
# Processing 1008 of 8762 batches (11 sequences)
# Processing 1009 of 8762 batches (11 sequences)
# Processing 1010 of 8762 batches (11 sequences)
# Processing 1011 of 8762 batches (11 sequences)
# Processing 1012 of 8762 batches (11 sequences)
# Processing 1013 of 8762 batches (11 sequences)
# Processing 1014 of 8762 batches (11 sequences)
# Processing 1015 of 8762 batches (11 sequences)
# Processing 1016 of 8762 batches (11 sequences)
# Processing 1017 of 8762 batches (11 sequences)
# Processing 1018 of 8762 batches (11 sequences)
# Processing 1019 of 8762 batches (11 sequences)
# Processing 1020 of 8762 batches (11 sequences)
# Processing 1021 of 8762 batches (11 sequences)
# Processing 1022 of 8762 batches (11 sequences)
# Processing 1023 of 8762 batches (11 sequences)
# Processing 1024 of 8762 batches (11 sequences)
# Processing 1025 of 8762 batches (11 sequences)
# Processing 1026 of 8762 batches (11 sequences)
# Processing 1027 of 8762 batches (11 sequences)
# Processing 1028 of 8762 batches (11 sequences)
# Processing 1029 of 8762 batches (11 sequences)
# Processing 1030 of 8762 batches (11 sequences)
# Processing 1031 of 8762 batches (11 sequences)
# Processing 1032 of 8762 batches (11 sequences)
# Processing 1033 of 8762 batches (11 sequences)
# Processing 1034 of 8762 batches (11 sequences)
# Processing 1035 of 8762 batches (11 sequences)
# Processing 1036 of 8762 batches (11 sequences)
# Processing 1037 of 8762 batches (11 sequences)
# Processing 1038 of 8762 batches (11 sequences)
# Processing 1039 of 8762 batches (11 sequences)
# Processing 1040 of 8762 batches (11 sequences)
# Processing 1041 of 8762 batches (11 sequences)
# ...
# Processing 3384 of 8762 batches (5 sequences)
# Processing 3385 of 8762 batches (5 sequences)
# Processing 3386 of 8762 batches (5 sequences)
# Processing 3387 of 8762 batches (5 sequences)
# Processing 3388 of 8762 batches (5 sequences)
# Processing 3389 of 8762 batches (5 sequences)
# Processing 3390 of 8762 batches (5 sequences)
# Processing 3391 of 8762 batches (5 sequences)
# Processing 3392 of 8762 batches (5 sequences)
# Processing 3393 of 8762 batches (5 sequences)
# Processing 3394 of 8762 batches (5 sequences)
# Processing 3395 of 8762 batches (5 sequences)
# Processing 3396 of 8762 batches (5 sequences)
# Processing 3397 of 8762 batches (5 sequences)
# Processing 3398 of 8762 batches (5 sequences)
# Processing 3399 of 8762 batches (5 sequences)
# Processing 3400 of 8762 batches (5 sequences)
# Processing 3401 of 8762 batches (5 sequences)
# Processing 3402 of 8762 batches (5 sequences)
# Processing 3403 of 8762 batches (5 sequences)
# Processing 3404 of 8762 batches (5 sequences)
# Processing 3405 of 8762 batches (5 sequences)
# Processing 3406 of 8762 batches (5 sequences)
# Processing 3407 of 8762 batches (5 sequences)
# Processing 3408 of 8762 batches (5 sequences)
# Processing 3409 of 8762 batches (5 sequences)
# Processing 3410 of 8762 batches (5 sequences)
# Processing 3411 of 8762 batches (5 sequences)
# Processing 3412 of 8762 batches (5 sequences)
# Processing 3413 of 8762 batches (5 sequences)
# Processing 3414 of 8762 batches (5 sequences)
# Processing 3415 of 8762 batches (5 sequences)
# Processing 3416 of 8762 batches (5 sequences)
# Processing 3417 of 8762 batches (5 sequences)
# Processing 3418 of 8762 batches (5 sequences)
# Processing 3419 of 8762 batches (5 sequences)
# Processing 3420 of 8762 batches (5 sequences)
# Processing 3421 of 8762 batches (5 sequences)
# Processing 3422 of 8762 batches (5 sequences)
# Processing 3423 of 8762 batches (5 sequences)
# Processing 3424 of 8762 batches (5 sequences)
# Processing 3425 of 8762 batches (5 sequences)
# Processing 3426 of 8762 batches (5 sequences)
# Processing 3427 of 8762 batches (5 sequences)
# Processing 3428 of 8762 batches (5 sequences)
# Processing 3429 of 8762 batches (5 sequences)
# Processing 3430 of 8762 batches (5 sequences)
# Processing 3431 of 8762 batches (5 sequences)
# Processing 3432 of 8762 batches (5 sequences)
# Processing 3433 of 8762 batches (5 sequences)
# Processing 3434 of 8762 batches (5 sequences)
# Processing 3435 of 8762 batches (5 sequences)
# Processing 3436 of 8762 batches (5 sequences)
# Processing 3437 of 8762 batches (5 sequences)
# Processing 3438 of 8762 batches (5 sequences)
# Processing 3439 of 8762 batches (5 sequences)
# Processing 3440 of 8762 batches (5 sequences)
# Processing 3441 of 8762 batches (5 sequences)
# Processing 3442 of 8762 batches (5 sequences)
# Processing 3443 of 8762 batches (5 sequences)
# Processing 3444 of 8762 batches (5 sequences)
# Processing 3445 of 8762 batches (5 sequences)
# Processing 3446 of 8762 batches (5 sequences)
# Processing 3447 of 8762 batches (5 sequences)
# Processing 3448 of 8762 batches (5 sequences)
# Processing 3449 of 8762 batches (5 sequences)
# Processing 3450 of 8762 batches (5 sequences)
# Processing 3451 of 8762 batches (5 sequences)
# Processing 3452 of 8762 batches (5 sequences)
# Processing 3453 of 8762 batches (5 sequences)
# Processing 3454 of 8762 batches (5 sequences)
# Processing 3455 of 8762 batches (5 sequences)
# Processing 3456 of 8762 batches (5 sequences)
# Processing 3457 of 8762 batches (5 sequences)
# Processing 3458 of 8762 batches (5 sequences)
# Processing 3459 of 8762 batches (5 sequences)
# Processing 3460 of 8762 batches (5 sequences)
# Processing 3461 of 8762 batches (5 sequences)
# Processing 3462 of 8762 batches (5 sequences)
# Processing 3463 of 8762 batches (5 sequences)
# Processing 3464 of 8762 batches (5 sequences)
# Processing 3465 of 8762 batches (5 sequences)
# Processing 3466 of 8762 batches (5 sequences)
# Processing 3467 of 8762 batches (5 sequences)
# Processing 3468 of 8762 batches (5 sequences)
# Processing 3469 of 8762 batches (5 sequences)
# Processing 3470 of 8762 batches (5 sequences)
# Processing 3471 of 8762 batches (5 sequences)
# Processing 3472 of 8762 batches (5 sequences)
# Processing 3473 of 8762 batches (5 sequences)
# Processing 3474 of 8762 batches (5 sequences)
# Processing 3475 of 8762 batches (5 sequences)
# Processing 3476 of 8762 batches (5 sequences)
# Processing 3477 of 8762 batches (5 sequences)
# Processing 3478 of 8762 batches (5 sequences)
# Processing 3479 of 8762 batches (5 sequences)
# Processing 3480 of 8762 batches (5 sequences)
# Processing 3481 of 8762 batches (5 sequences)
# Processing 3482 of 8762 batches (5 sequences)
# Processing 3483 of 8762 batches (5 sequences)
# Processing 3484 of 8762 batches (5 sequences)
# Processing 3485 of 8762 batches (5 sequences)
# Processing 3486 of 8762 batches (5 sequences)
# Processing 3487 of 8762 batches (5 sequences)
# Processing 3488 of 8762 batches (5 sequences)
# Processing 3489 of 8762 batches (5 sequences)
# Processing 3490 of 8762 batches (5 sequences)
# Processing 3491 of 8762 batches (5 sequences)
# Processing 3492 of 8762 batches (5 sequences)
# Processing 3493 of 8762 batches (5 sequences)
# Processing 3494 of 8762 batches (5 sequences)
# Processing 3495 of 8762 batches (5 sequences)
# Processing 3496 of 8762 batches (5 sequences)
# Processing 3497 of 8762 batches (5 sequences)
# Processing 3498 of 8762 batches (5 sequences)
# Processing 3499 of 8762 batches (5 sequences)
# Processing 3500 of 8762 batches (5 sequences)
# Processing 3501 of 8762 batches (5 sequences)
# Processing 3502 of 8762 batches (5 sequences)
# Processing 3503 of 8762 batches (5 sequences)
# Processing 3504 of 8762 batches (5 sequences)
# Processing 3505 of 8762 batches (5 sequences)
# Processing 3506 of 8762 batches (5 sequences)
# Processing 3507 of 8762 batches (5 sequences)
# Processing 3508 of 8762 batches (5 sequences)
# Processing 3509 of 8762 batches (5 sequences)
# Processing 3510 of 8762 batches (5 sequences)
# Processing 3511 of 8762 batches (5 sequences)
# Processing 3512 of 8762 batches (5 sequences)
# Processing 3513 of 8762 batches (5 sequences)
# Processing 3514 of 8762 batches (5 sequences)
# Processing 3515 of 8762 batches (5 sequences)
# Processing 3516 of 8762 batches (5 sequences)
# Processing 3517 of 8762 batches (5 sequences)
# Processing 3518 of 8762 batches (5 sequences)
# Processing 3519 of 8762 batches (5 sequences)
# Processing 3520 of 8762 batches (5 sequences)
# Processing 3521 of 8762 batches (5 sequences)
# Processing 3522 of 8762 batches (5 sequences)
# Processing 3523 of 8762 batches (5 sequences)
# Processing 3524 of 8762 batches (5 sequences)
# Processing 3525 of 8762 batches (5 sequences)
# Processing 3526 of 8762 batches (5 sequences)
# Processing 3527 of 8762 batches (5 sequences)
# Processing 3528 of 8762 batches (5 sequences)
# Processing 3529 of 8762 batches (5 sequences)
# Processing 3530 of 8762 batches (5 sequences)
# Processing 3531 of 8762 batches (5 sequences)
# Processing 3532 of 8762 batches (5 sequences)
# Processing 3533 of 8762 batches (5 sequences)
# Processing 3534 of 8762 batches (5 sequences)
# Processing 3535 of 8762 batches (5 sequences)
# Processing 3536 of 8762 batches (5 sequences)
# Processing 3537 of 8762 batches (5 sequences)
# Processing 3538 of 8762 batches (5 sequences)
# Processing 3539 of 8762 batches (5 sequences)
# Processing 3540 of 8762 batches (5 sequences)
# Processing 3541 of 8762 batches (5 sequences)
# Processing 3542 of 8762 batches (5 sequences)
# Processing 3543 of 8762 batches (5 sequences)
# Processing 3544 of 8762 batches (5 sequences)
# Processing 3545 of 8762 batches (5 sequences)
# Processing 3546 of 8762 batches (5 sequences)
# Processing 3547 of 8762 batches (5 sequences)
# Processing 3548 of 8762 batches (5 sequences)
# Processing 3549 of 8762 batches (5 sequences)
# Processing 3550 of 8762 batches (5 sequences)
# Processing 3551 of 8762 batches (5 sequences)
# Processing 3552 of 8762 batches (5 sequences)
# Processing 3553 of 8762 batches (5 sequences)
# Processing 3554 of 8762 batches (5 sequences)
# Processing 3555 of 8762 batches (5 sequences)
# Processing 3556 of 8762 batches (5 sequences)
# Processing 3557 of 8762 batches (5 sequences)
# Processing 3558 of 8762 batches (5 sequences)
# Processing 3559 of 8762 batches (5 sequences)
# Processing 3560 of 8762 batches (5 sequences)
# Processing 3561 of 8762 batches (5 sequences)
# Processing 3562 of 8762 batches (5 sequences)
# Processing 3563 of 8762 batches (5 sequences)
# Processing 3564 of 8762 batches (5 sequences)
# Processing 3565 of 8762 batches (5 sequences)
# Processing 3566 of 8762 batches (5 sequences)
# Processing 3567 of 8762 batches (5 sequences)
# Processing 3568 of 8762 batches (5 sequences)
# Processing 3569 of 8762 batches (5 sequences)
# Processing 3570 of 8762 batches (5 sequences)
# Processing 3571 of 8762 batches (5 sequences)
# Processing 3572 of 8762 batches (5 sequences)
# Processing 3573 of 8762 batches (5 sequences)
# Processing 3574 of 8762 batches (5 sequences)
# Processing 3575 of 8762 batches (5 sequences)
# Processing 3576 of 8762 batches (5 sequences)
# Processing 3577 of 8762 batches (5 sequences)
# Processing 3578 of 8762 batches (5 sequences)
# Processing 3579 of 8762 batches (5 sequences)
# Processing 3580 of 8762 batches (5 sequences)
# Processing 3581 of 8762 batches (5 sequences)
# Processing 3582 of 8762 batches (5 sequences)
# Processing 3583 of 8762 batches (5 sequences)
# Processing 3584 of 8762 batches (5 sequences)
# Processing 3585 of 8762 batches (5 sequences)
# Processing 3586 of 8762 batches (5 sequences)
# Processing 3587 of 8762 batches (5 sequences)
# Processing 3588 of 8762 batches (5 sequences)
# Processing 3589 of 8762 batches (5 sequences)
# Processing 3590 of 8762 batches (5 sequences)
# Processing 3591 of 8762 batches (5 sequences)
# Processing 3592 of 8762 batches (5 sequences)
# Processing 3593 of 8762 batches (5 sequences)
# Processing 3594 of 8762 batches (5 sequences)
# Processing 3595 of 8762 batches (5 sequences)
# Processing 3596 of 8762 batches (5 sequences)
# Processing 3597 of 8762 batches (5 sequences)
# Processing 3598 of 8762 batches (5 sequences)
# Processing 3599 of 8762 batches (5 sequences)
# Processing 3600 of 8762 batches (5 sequences)
# Processing 3601 of 8762 batches (5 sequences)
# Processing 3602 of 8762 batches (5 sequences)
# Processing 3603 of 8762 batches (5 sequences)
# Processing 3604 of 8762 batches (5 sequences)
# Processing 3605 of 8762 batches (5 sequences)
# Processing 3606 of 8762 batches (5 sequences)
# Processing 3607 of 8762 batches (5 sequences)
# Processing 3608 of 8762 batches (5 sequences)
# Processing 3609 of 8762 batches (5 sequences)
# Processing 3610 of 8762 batches (5 sequences)
# Processing 3611 of 8762 batches (5 sequences)
# Processing 3612 of 8762 batches (5 sequences)
# Processing 3613 of 8762 batches (5 sequences)
# Processing 3614 of 8762 batches (5 sequences)
# Processing 3615 of 8762 batches (5 sequences)
# Processing 3616 of 8762 batches (5 sequences)
# Processing 3617 of 8762 batches (5 sequences)
# Processing 3618 of 8762 batches (5 sequences)
# Processing 3619 of 8762 batches (5 sequences)
# Processing 3620 of 8762 batches (5 sequences)
# Processing 3621 of 8762 batches (5 sequences)
# Processing 3622 of 8762 batches (5 sequences)
# Processing 3623 of 8762 batches (5 sequences)
# Processing 3624 of 8762 batches (5 sequences)
# Processing 3625 of 8762 batches (5 sequences)
# Processing 3626 of 8762 batches (5 sequences)
# Processing 3627 of 8762 batches (5 sequences)
# Processing 3628 of 8762 batches (5 sequences)
# Processing 3629 of 8762 batches (5 sequences)
# Processing 3630 of 8762 batches (5 sequences)
# Processing 3631 of 8762 batches (5 sequences)
# Processing 3632 of 8762 batches (5 sequences)
# Processing 3633 of 8762 batches (5 sequences)
# Processing 3634 of 8762 batches (5 sequences)
# Processing 3635 of 8762 batches (5 sequences)
# Processing 3636 of 8762 batches (5 sequences)
# Processing 3637 of 8762 batches (5 sequences)
# Processing 3638 of 8762 batches (5 sequences)
# Processing 3639 of 8762 batches (5 sequences)
# Processing 3640 of 8762 batches (5 sequences)
# Processing 3641 of 8762 batches (5 sequences)
# Processing 3642 of 8762 batches (5 sequences)
# Processing 3643 of 8762 batches (5 sequences)
# Processing 3644 of 8762 batches (5 sequences)
# Processing 3645 of 8762 batches (5 sequences)
# Processing 3646 of 8762 batches (5 sequences)
# Processing 3647 of 8762 batches (5 sequences)
# Processing 3648 of 8762 batches (5 sequences)
# Processing 3649 of 8762 batches (5 sequences)
# Processing 3650 of 8762 batches (5 sequences)
# Processing 3651 of 8762 batches (5 sequences)
# Processing 3652 of 8762 batches (5 sequences)
# Processing 3653 of 8762 batches (5 sequences)
# Processing 3654 of 8762 batches (5 sequences)
# Processing 3655 of 8762 batches (5 sequences)
# Processing 3656 of 8762 batches (5 sequences)
# Processing 3657 of 8762 batches (5 sequences)
# Processing 3658 of 8762 batches (5 sequences)
# Processing 3659 of 8762 batches (5 sequences)
# Processing 3660 of 8762 batches (5 sequences)
# Processing 3661 of 8762 batches (5 sequences)
# Processing 3662 of 8762 batches (5 sequences)
# Processing 3663 of 8762 batches (5 sequences)
# Processing 3664 of 8762 batches (5 sequences)
# Processing 3665 of 8762 batches (5 sequences)
# Processing 3666 of 8762 batches (5 sequences)
# Processing 3667 of 8762 batches (5 sequences)
# Processing 3668 of 8762 batches (5 sequences)
# Processing 3669 of 8762 batches (5 sequences)
# Processing 3670 of 8762 batches (5 sequences)
# Processing 3671 of 8762 batches (5 sequences)
# Processing 3672 of 8762 batches (5 sequences)
# Processing 3673 of 8762 batches (5 sequences)
# Processing 3674 of 8762 batches (5 sequences)
# Processing 3675 of 8762 batches (5 sequences)
# Processing 3676 of 8762 batches (5 sequences)
# Processing 3677 of 8762 batches (5 sequences)
# Processing 3678 of 8762 batches (5 sequences)
# Processing 3679 of 8762 batches (5 sequences)
# Processing 3680 of 8762 batches (5 sequences)
# Processing 3681 of 8762 batches (5 sequences)
# Processing 3682 of 8762 batches (5 sequences)
# Processing 3683 of 8762 batches (5 sequences)
# Processing 3684 of 8762 batches (5 sequences)
# Processing 3685 of 8762 batches (5 sequences)
# Processing 3686 of 8762 batches (5 sequences)
# Processing 3687 of 8762 batches (5 sequences)
# Processing 3688 of 8762 batches (5 sequences)
# Processing 3689 of 8762 batches (5 sequences)
# Processing 3690 of 8762 batches (5 sequences)
# Processing 3691 of 8762 batches (5 sequences)
# Processing 3692 of 8762 batches (5 sequences)
# Processing 3693 of 8762 batches (5 sequences)
# Processing 3694 of 8762 batches (5 sequences)
# Processing 3695 of 8762 batches (5 sequences)
# Processing 3696 of 8762 batches (5 sequences)
# Processing 3697 of 8762 batches (5 sequences)
# Processing 3698 of 8762 batches (5 sequences)
# Processing 3699 of 8762 batches (5 sequences)
# Processing 3700 of 8762 batches (5 sequences)
# Processing 3701 of 8762 batches (5 sequences)
# Processing 3702 of 8762 batches (5 sequences)
# Processing 3703 of 8762 batches (5 sequences)
# Processing 3704 of 8762 batches (5 sequences)
# Processing 3705 of 8762 batches (5 sequences)
# Processing 3706 of 8762 batches (5 sequences)
# Processing 3707 of 8762 batches (5 sequences)
# Processing 3708 of 8762 batches (5 sequences)
# Processing 3709 of 8762 batches (5 sequences)
# Processing 3710 of 8762 batches (5 sequences)
# Processing 3711 of 8762 batches (5 sequences)
# Processing 3712 of 8762 batches (5 sequences)
# Processing 3713 of 8762 batches (5 sequences)
# Processing 3714 of 8762 batches (5 sequences)
# Processing 3715 of 8762 batches (5 sequences)
# Processing 3716 of 8762 batches (5 sequences)
# Processing 3717 of 8762 batches (5 sequences)
# Processing 3718 of 8762 batches (5 sequences)
# Processing 3719 of 8762 batches (5 sequences)
# Processing 3720 of 8762 batches (5 sequences)
# Processing 3721 of 8762 batches (5 sequences)
# Processing 3722 of 8762 batches (5 sequences)
# Processing 3723 of 8762 batches (5 sequences)
# Processing 3724 of 8762 batches (5 sequences)
# Processing 3725 of 8762 batches (5 sequences)
# Processing 3726 of 8762 batches (5 sequences)
# Processing 3727 of 8762 batches (5 sequences)
# Processing 3728 of 8762 batches (5 sequences)
# Processing 3729 of 8762 batches (5 sequences)
# Processing 3730 of 8762 batches (5 sequences)

# %% [markdown]
# ## Step 4: Convert to Embeddings File

# %%
# !python sequence_model/map_gene_symbol_to_protein_ids.py \
    --fasta_path ./data/{NAME}.fa \
    --save_path ./data/{NAME}.gene_symbol_to_protein_ID.json


# !python sequence_model/convert_protein_embeddings_to_gene_embeddings.py \
    --embedding_dir ./data/{NAME}.clean.fa_esm1b \
    --gene_symbol_to_protein_ids_path ./data/{NAME}.gene_symbol_to_protein_ID.json \
    --embedding_model ESM1b \
    --save_path ./data/{NAME}.gene_symbol_to_embedding_ESM1b.pt

# %% [markdown]
# ## STEP 5: Running SPEAR

# %%
# Your final embeddings will be located at: 
os.path.abspath(f"./data/{NAME}.gene_symbol_to_embedding_ESM1b.pt")
